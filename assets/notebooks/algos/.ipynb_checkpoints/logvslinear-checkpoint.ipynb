# %%
import numpy as np 
from matplotlib import pyplot as plt 


x = np.arange(1,64) 
y1 = np.log2(x)
y2 = x
plt.xlabel("size of array") 
plt.ylabel("number of comparisons") 
plt.plot(x,y1, 'r-', label="binary search")
plt.plot(x,y2, 'b-',label="linear search") 
plt.legend()
plt.savefig('logvslinear.png')
plt.show()
